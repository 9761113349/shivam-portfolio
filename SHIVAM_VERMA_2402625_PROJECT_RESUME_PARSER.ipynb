# %% [markdown]
# <a href="https://colab.research.google.com/github/9761113349/shivam-portfolio/blob/main/SHIVAM_VERMA_2402625_PROJECT_RESUME_PARSER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import spacy
import pickle
import random
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import math
import nltk
from textblob import TextBlob as tb
warnings.filterwarnings('ignore')
from sklearn.naive_bayes import MultinomialNB
from sklearn.multiclass import OneVsRestClassifier
from sklearn import metrics
from sklearn.metrics import accuracy_score
from pandas.plotting import scatter_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# %%
data1 = pd.read_csv("/content/drive/MyDrive/nlp_review/UpdatedResumeDataSet.csv")

# %%
import pickle

# Open the file and load the data
with open('/content/drive/MyDrive/nlp_review/train_data.pkl', 'rb') as infile:
    train_data = pickle.load(infile)

print(type(train_data))  # Check the type of loaded data
# Out:
# <class 'list'>

# %%
train_data[0]
# Out:
# ('Govardhana K Senior Software Engineer  Bengaluru, Karnataka, Karnataka - Email me on Indeed: indeed.com/r/Govardhana-K/ b2de315d95905b68  Total IT experience 5 Years 6 Months Cloud Lending Solutions INC 4 Month • Salesforce Developer Oracle 5 Years 2 Month • Core Java Developer Languages Core Java, Go Lang Oracle PL-SQL programming, Sales Force Developer with APEX.  Designations & Promotions  Willing to relocate: Anywhere  WORK EXPERIENCE  Senior Software Engineer  Cloud Lending Solutions -  Bangalore, Karnataka -  January 2018 to Present  Present  Senior Consultant  Oracle -  Bangalore, Karnataka -  November 2016 to December 2017  Staff Consultant  Oracle -  Bangalore, Karnataka -  January 2014 to October 2016  Associate Consultant  Oracle -  Bangalore, Karnataka -  November 2012 to December 2013  EDUCATION  B.E in Computer Science Engineering  Adithya Institute of Technology -  Tamil Nadu  September 2008 to June 2012  https://www.indeed.com/r/Govardhana-K/b2de315d95905b68?isid=re
# ...

# %%
nlp=spacy.blank('en')

def train_model(train_data):
  if 'ner' not in nlp.pipe_names:
    ner=nlp.create_pipe('ner')
    nlp.add_pipe(ner,last=True)

# We add labels in the NLP Pipelines
  for _, annotation in train_data:
    for ent in annotation['entities']:
      ner.add_label(ent[2])

# get names of other pipes to disable them during training
  other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
  with nlp.disable_pipes(*other_pipes):
    optimizer = nlp.begin_training()
    for itn in range(10):
      print("Starting iteration "+str(itn))
      random.shuffle(train_data)
      losses = {}
      index=0
      for text, annotations in train_data:
        # print (index)
        try:
          nlp.update(
              [text], #batch of texts
              [annotations], # batch of annotations
              drop=0.2, #dropout - make it harder to memorise
              sgd=optimizer, #callable to update weights
              losses=losses
          )
        except Exception as e:
          pass
            # print(text)

      print(losses)

# %%
# !pip install ner
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ner: filename=ner-0.1-py3-none-any.whl size=5508 sha256=3d6d47a834aff21f7feffb90193fdfc94105141594d5091fcec8c40e3e67078d
#   Stored in directory: /root/.cache/pip/wheels/f3/63/fd/fd3dda12a6fb5e9d9b8b8b580ea88c83b2de4cb1163ca60e88
# Successfully built ner
# ...

# %%
def train_model(data):
    # Your training logic here
    print("Training model with data:", data)

# Call the function
train_model(train_data)
# Out:
# Training model with data: [('Govardhana K Senior Software Engineer  Bengaluru, Karnataka, Karnataka - Email me on Indeed: indeed.com/r/Govardhana-K/ b2de315d95905b68  Total IT experience 5 Years 6 Months Cloud Lending Solutions INC 4 Month • Salesforce Developer Oracle 5 Years 2 Month • Core Java Developer Languages Core Java, Go Lang Oracle PL-SQL programming, Sales Force Developer with APEX.  Designations & Promotions  Willing to relocate: Anywhere  WORK EXPERIENCE  Senior Software Engineer  Cloud Lending Solutions -  Bangalore, Karnataka -  January 2018 to Present  Present  Senior Consultant  Oracle -  Bangalore, Karnataka -  November 2016 to December 2017  Staff Consultant  Oracle -  Bangalore, Karnataka -  January 2014 to October 2016  Associate Consultant  Oracle -  Bangalore, Karnataka -  November 2012 to December 2013  EDUCATION  B.E in Computer Science Engineering  Adithya Institute of Technology -  Tamil Nadu  September 2008 to June 2012  https://www.indeed.com/r/Govardhana
# ...

# %%
# !pip install nlp
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 23.4 MB/s eta 0:00:00
# ...

# %%
import spacy

# Load the correct language model
nlp = spacy.load("en_core_web_sm")

# Process a sample sentence
doc = nlp("This is a sentence.")

# Define the function correctly
def parse_resume():
    print("Parsing resume...")
    nlp = spacy.load("en_core_web_sm")  # Correct indentation

# %%
text = ""
for token in doc:
    text += token.text + " "  # Add a space between tokens
print(text)
# Out:
# This is a sentence .

# %%
import spacy

# Load a spaCy model
nlp = spacy.load("en_core_web_sm")

# Process a text
doc = nlp("This is an example sentence.")

# Extract text from tokens
text = ""
for token in doc:
    text += token.text + " "  # Add a space between tokens

print(text.strip())  # Remove trailing space
# Out:
# This is an example sentence .

# %%
# Install the PyMuPDF library
# !pip install PyMuPDF

# Import the required modules
import sys
import fitz

# Path to the PDF file
fname = '/content/drive/MyDrive/nlp_review/SHIVAM VERMA RESUME COMPUTER SCIENCE.pdf'

# Open the PDF file
doc = fitz.open(fname)

# Process the PDF file (example: extract text from the first page)
page = doc.load_page(0)  # Load the first page (0-based index)
text = page.get_text()   # Extract text from the page
print(text)
# Out:
# ...
# SHIVAM VERMA
# Contact No: 9761113349, 7017234990
# Email-Id: shivamverama01@gmail.com
# Address: Tyagi Colony, Sadabad
#
#
#
#     TECHNICAL SKILLS
#
# Python Programming
# (Beginner)
#
# My SQL (Beginner)
#
# Data Mining (Beginner)
#
# Microsoft Office
# (Word, Excel, Power point)
#
# Typing ( Hindi & English).
#
# Sap Logon (ERP).
#
# Romans Cad (SL average).
#
# Shoe Master Software.
#
# SOFT SKILLS
#
# Leadership Skill.
#
# Communication Skill
#
# Team Player.
#
# Time Management
#
# Managerial Skill.
#
# CERTIFICATE
#
# PYTHON PRACTICE
# CODE Approved By
# GREAT LEARNING
# ACADEMY( 2024)
#
#
#
#
#
# Introduction to SAP
# Approved By Great
# Learning(2023)
#
#
# 3 Months, CCC course
# approved by NIELIT
# (2019).
#
#
# 1 Month, Fundamental of
# Digital Marketing
# approved by
# GOOGLE(2019).
#
#
# 3 Months, NDLM
# (National Digital
# Literacy Mission)
# approved by NIELIT
# (2015).
# Date: -
# Place: -
# Yours Faithfully:
#
#
# SHIVAM VERMA
#
#
# Career Objective:
#
# ...

# %%
import re

# Define skill keywords
skill_keywords = {"Python", "JavaScript", "Power BI", "Node.js", "Machine Learning", "SQL"}

def extract_job_skills(text):
    """Extract required job skills from job description"""
    found_skills = set()
    for skill in skill_keywords:
        if re.search(r"\b" + re.escape(skill) + r"\b", text, re.IGNORECASE):
            found_skills.add(skill)
    return found_skills

# Example job description
job_description = "We are looking for a developer skilled in Python and SQL."

# Extract skills from the job description
job_skills = extract_job_skills(job_description)

print("Job Skills:", job_skills)
# Out:
# Job Skills: {'SQL', 'Python'}

# %%
import re

# Define skill keywords
skill_keywords = {"Python", "JavaScript", "React", "Node.js", "Machine Learning", "SQL"}

def extract_skills(text):
    """Extract required skills from text"""
    found_skills = set()
    for skill in skill_keywords:
        if re.search(r"\b" + re.escape(skill) + r"\b", text, re.IGNORECASE):
            found_skills.add(skill)
    return found_skills

# Example job description
job_description = "We are looking for a developer skilled in Python, React, and SQL."
job_skills = extract_skills(job_description)

# Example resume text

# Example resume text
resume_text = "Python, JavaScript, and Machine Learning."
resume_skills = extract_skills(resume_text)

# Matching skills
matched_skills = resume_skills.intersection(job_skills)
missing_skills = job_skills.difference(resume_skills)

# Calculate Matching Score
match_score = len(matched_skills) / len(job_skills) * 100 if job_skills else 0

print("Job Skills:", job_skills)
print("Resume Skills:", resume_skills)
print("Matched Skills:", matched_skills)
print("Missing Skills:", missing_skills)
print("Match Score: {:.2f}%".format(match_score))
# Out:
# Job Skills: {'React', 'SQL', 'Python'}
# Resume Skills: {'JavaScript', 'Machine Learning', 'Python'}
# Matched Skills: {'Python'}
# Missing Skills: {'React', 'SQL'}
# Match Score: 33.33%

# %%
text = ""
for page in doc:
    text += page.get_text("text")  # Extract text properly
tx = " ".join(text.split('\n'))
print(tx)
# Out:
# SHIVAM VERMA  Contact No: 9761113349, 7017234990  Email-Id: shivamverama01@gmail.com  Address: Tyagi Colony, Sadabad            TECHNICAL SKILLS    Python Programming  (Beginner)    My SQL (Beginner)    Data Mining (Beginner)    Microsoft Office  (Word, Excel, Power point)    Typing ( Hindi & English).    Sap Logon (ERP).    Romans Cad (SL average).    Shoe Master Software.    SOFT SKILLS    Leadership Skill.    Communication Skill    Team Player.    Time Management    Managerial Skill.    CERTIFICATE    PYTHON PRACTICE  CODE Approved By  GREAT LEARNING  ACADEMY( 2024)            Introduction to SAP  Approved By Great  Learning(2023)      3 Months, CCC course  approved by NIELIT  (2019).      1 Month, Fundamental of  Digital Marketing  approved by  GOOGLE(2019).      3 Months, NDLM  (National Digital  Literacy Mission)  approved by NIELIT  (2015).  Date: -  Place: -  Yours Faithfully:      SHIVAM VERMA      Career Objective:    To work in an organization where I can acquire new knowl
# ...

# %%
# !pip install spacy-transformers

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

ground_truth = [1, 0, 1]  # True labels
predictions = [1, 0, 1]   # Predicted labels (same length)

precision = precision_score(ground_truth, predictions, average='micro')
recall = recall_score(ground_truth, predictions, average='micro')
f1 = f1_score(ground_truth, predictions, average='micro')

print(f"Precision: {precision}, Recall: {recall}, F1-score: {f1}")
# Out:
# Precision: 1.0, Recall: 1.0, F1-score: 1.0

# %%
from PIL import Image

# Load an image
image = Image.open("/content/drive/MyDrive/nlp_review/SH.jpg")
image.show()  # This will display the image using a default viewer

# %%
# !pip install pytesseract

# %%
# !apt install -y tesseract-ocr
# !pip install Tesseract-OCR
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.
# ...
#   Using cached tesseract-ocr-0.0.1.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for Tesseract-OCR
#   Running setup.py clean for Tesseract-OCR
# Failed to build Tesseract-OCR
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (Tesseract-OCR)

# %%
pip install pytesseract

# %%
import pytesseract
from PIL import Image

# If needed, specify the path to the Tesseract executable:
# pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'  # Linux
# pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'  # Windows

# Load and OCR an image
image = Image.open("/content/drive/MyDrive/nlp_review/SH.jpg")  # Replace with your image path
text = pytesseract.image_to_string(image)

print(text)
# Out:
# www shardacscacademy.co.in
#
# MTT
#
#
#
# eq)
# ZH
#
# ABE
# Aue
#
# 4 z
#
# me OP
# BEAR
#
# LEG

# %%
# !pip install Tesseract-OCR
# Out:
# ...
#   Using cached tesseract-ocr-0.0.1.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for Tesseract-OCR
#   Running setup.py clean for Tesseract-OCR
# Failed to build Tesseract-OCR
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (Tesseract-OCR)
# 'content/drive/MyDrive/nlp_review/SH.jpg'

# %%
import cv2
import pytesseract
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread("/content/drive/MyDrive/nlp_review/SH.jpg")

# Check if the image is loaded correctly
if image is None:
    print("Error: Image not found. Check the file path!")
else:
    # Convert to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply thresholding to improve OCR accuracy
    gray = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]

    # Optional: Apply noise reduction
    gray = cv2.medianBlur(gray, 3)

    # ✅ Use Matplotlib to Display Image in Colab
    plt.figure(figsize=(6, 6))
    plt.imshow(gray, cmap="gray")
    plt.title("Processed Image")
    plt.axis("off")
    plt.show()

    # Perform OCR
    text = pytesseract.image_to_string(gray)
    print("Extracted Text:\n", text)
# Out:
# Extracted Text:
#  SHARAD CCACADEM
#
# ve WERAR ah

# %%
# !pip install pytesseract

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
# !apt-get update
# !apt-get install -y tesseract-ocr
# !pip install pytesseract
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:10 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [73.0 kB]
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,697 kB]
# ...

# %%
import React, { useState } from "react";
import Tesseract from "tesseract.js";

const ImageToText = () => {
  const [image, setImage] = useState(null);
  const [text, setText] = useState("");
  const [loading, setLoading] = useState(false);

  const handleImageChange = (e) => {
    const file = e.target.files[0];
    if (file) {
      setImage(URL.createObjectURL(file));
    }
  };

  const extractText = async () => {
    if (!image) return alert("Please select an image first.");

    setLoading(true);

    try {
      const { data } = await Tesseract.recognize(image, "eng", {
        logger: (m) => console.log(m), // Logs progress
      });
      setText(data.text);
    } catch (error) {
      console.error("Error extracting text:", error);
    }

    setLoading(false);
  };

  return (
    <div>
      <h2>Extract Text from Image</h2>
      <input type="file" accept="image/*" onChange={handleImageChange} />
      {image && <img src={image} alt="Uploaded" style={{ maxWidth: "300px" }} />}
      <button onClick={extractText} disabled={loading}>
        {loading ? "Extracting..." : "Extract Text"}
      </button>
      <textarea value={text} readOnly rows={10} cols={50}></textarea>
    </div>
  );
};

export default ImageToText;
# Out:
#   File "<ipython-input-56-1da833bb4b0d>", line 1
#     import React, { useState } from "react";
#                   ^
# SyntaxError: invalid syntax

# %%
# !pip install react
# !pip install tesseract.js
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for react: filename=react-4.3.0-py3-none-any.whl size=4838 sha256=a7adbf7bd68a7356cf2c6a76730ce912e71d353d19573217fa94c5dce8808616
#   Stored in directory: /root/.cache/pip/wheels/d1/e4/5d/45c6707d8f0b59240ad3821936ffc9f0b8a7dc18d6aaf5db06
# ...
#   Created wheel for optional-django: filename=optional_django-0.3.0-py3-none-any.whl size=10537 sha256=9d106ed83ae19798e90def3709f83f03b1ba944ca643e86677e8ae2acf4b5483
#   Stored in directory: /root/.cache/pip/wheels/5b/c1/35/ec2685cbe2f80f1dc0472cdfdb71abb8e28f82ce53e7d9a981
# Successfully built react optional-django
# ...
# ERROR: Could not find a version that satisfies the requirement tesseract.js (from versions: none)
# ERROR: No matching distribution found for tesseract.js

# %%
# !pip install pytesseract
# !pip install tesseract

# %%
# !pip install opencv-python
# !pip install pytesseract
# !sudo apt-get install tesseract-ocr
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 47 not upgraded.

# %%
pip install opencv-python pytesseract

# %%
import cv2
import pytesseract

# %%
# !pip install markupsafe jinja2 spacy
# !pip install unicode

# %%
import spacy

# Load the pre-trained spaCy model
nlp_model = spacy.load("en_core_web_sm")

# Define your text
tx = "Samsung is looking at buying in India startup for Rs 1 billion."

# Process the text
doc = nlp_model(tx)

# Extract and print the named entities
for ent in doc.ents:
    print(f'{ent.label_.upper():{30}} - {ent.text}')
# Out:
# ORG                            - Samsung
# GPE                            - India
# LAW                            - Rs 1 billion

# %%
import pandas as pd

# Example: Create a sample DataFrame
data1 = pd.DataFrame({'resume': ["Software Engineer with 5 years experience", "Data Scientist skilled in Python"]})

# Add an empty column named 'cleaned_resume'
data1['cleaned_resume'] = ''

# Display the first few rows
print(data1.head())
# Out:
#                                       resume cleaned_resume
# 0  Software Engineer with 5 years experience
# 1           Data Scientist skilled in Python

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=data1)
# Out:
# https://docs.google.com/spreadsheets/d/1Olu78kv2Fg7MoGjBd7HOYy4ML3KzyKe-KR9OUc78beA/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1Olu78kv2Fg7MoGjBd7HOYy4ML3KzyKe-KR9OUc78beA/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from matplotlib import pyplot as plt
_df_0['index'].plot(kind='hist', bins=20, title='index')
plt.gca().spines[['top', 'right',]].set_visible(False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-32d0ed34254b> in <cell line: 0>()
#       1 from matplotlib import pyplot as plt
# ----> 2 _df_0['index'].plot(kind='hist', bins=20, title='index')
#       3 plt.gca().spines[['top', 'right',]].set_visible(False)
#
# NameError: name '_df_0' is not defined

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  counted = (series['index']
                .value_counts()
              .reset_index(name='counts')
              .rename({'index': 'index'}, axis=1)
              .sort_values('index', ascending=True))
  xs = counted['index']
  ys = counted['counts']
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_2.sort_values('index', ascending=True)
for i, (series_name, series) in enumerate(df_sorted.groupby('resume')):
  _plot_series(series, series_name, i)
  fig.legend(title='resume', bbox_to_anchor=(1, 1), loc='upper left')
sns.despine(fig=fig, ax=ax)
plt.xlabel('index')
_ = plt.ylabel('count()')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-67bee9bd9103> in <cell line: 0>()
#      13
#      14 fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# ---> 15 df_sorted = _df_2.sort_values('index', ascending=True)
#      16 for i, (series_name, series) in enumerate(df_sorted.groupby('resume')):
#      17   _plot_series(series, series_name, i)
#
# NameError: name '_df_2' is not defined

# %%
from matplotlib import pyplot as plt
_df_3['index'].plot(kind='line', figsize=(8, 4), title='index')
plt.gca().spines[['top', 'right']].set_visible(False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-c8f7611b982c> in <cell line: 0>()
#       1 from matplotlib import pyplot as plt
# ----> 2 _df_3['index'].plot(kind='line', figsize=(8, 4), title='index')
#       3 plt.gca().spines[['top', 'right']].set_visible(False)
#
# NameError: name '_df_3' is not defined

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_0.groupby('resume').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-9e16a6da115b> in <cell line: 0>()
#       1 from matplotlib import pyplot as plt
#       2 import seaborn as sns
# ----> 3 _df_0.groupby('resume').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
#       4 plt.gca().spines[['top', 'right',]].set_visible(False)
#
# NameError: name '_df_0' is not defined

# %%
import pandas as pd

print(data1.columns)  # Lists all available columns
# Out:
# Index(['resume', 'cleaned_resume'], dtype='object')

# %%
print(data1.head())  # Check if the correct column is present
# Out:
#                                       resume cleaned_resume
# 0  Software Engineer with 5 years experience
# 1           Data Scientist skilled in Python

# %%
# Install pandas
# !pip install pandas

# Import pandas
import pandas as pd

# Load the CSV file
data1 = pd.read_csv("/content/drive/MyDrive/nlp_review/UpdatedResumeDataSet.csv")

# Display the first few rows of the dataset
print(data1.head())
# Out:
# ...
#        Category                                             Resume
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...

# %%
print ("Displaying the distinct categories of resume:\n\n ")
print (data1['Category'].unique())
# Out:
# Displaying the distinct categories of resume:
#
#
# ['Data Science' 'HR' 'Advocate' 'Arts' 'Web Designing'
#  'Mechanical Engineer' 'Sales' 'Health and fitness' 'Civil Engineer'
#  'Java Developer' 'Business Analyst' 'SAP Developer' 'Automation Testing'
#  'Electrical Engineering' 'Operations Manager' 'Python Developer'
#  'DevOps Engineer' 'Network Security Engineer' 'PMO' 'Database' 'Hadoop'
#  'ETL Developer' 'DotNet Developer' 'Blockchain' 'Testing']

# %%
print ("Displaying the distinct categories of resume and the number of records belonging to each category:\n\n")
print (data1['Category'].value_counts())
# Out:
# Displaying the distinct categories of resume and the number of records belonging to each category:
#
#
# Category
# Java Developer               84
# Testing                      70
# DevOps Engineer              55
# Python Developer             48
# Web Designing                45
# HR                           44
# Hadoop                       42
# Sales                        40
# Data Science                 40
# Mechanical Engineer          40
# ETL Developer                40
# Blockchain                   40
# Operations Manager           40
# Arts                         36
# Database                     33
# Health and fitness           30
# PMO                          30
# Electrical Engineering       30
# Business Analyst             28
# DotNet Developer             28
# Automation Testing           26
# Network Security Engineer    25
# Civil Engineer               24
# SAP Developer                24
# Advocate                     20
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(20,5))
plt.xticks(rotation=90)
ax=sns.countplot(x="Category", data=data1)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.01 , p.get_height() * 1.01))
plt.grid()

# %%
from matplotlib.gridspec import GridSpec
targetCounts = data1['Category'].value_counts()
targetLabels  = data1['Category'].unique()
# Make square figures and axes
plt.figure(1, figsize=(22,22))
the_grid = GridSpec(2, 2)


cmap = plt.get_cmap('coolwarm')
plt.subplot(the_grid[0, 1], aspect=1, title='CATEGORY DISTRIBUTION')

source_pie = plt.pie(targetCounts, labels=targetLabels, autopct='%1.1f%%', shadow=True)
plt.show()

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
from google.colab import files

# Upload the file
uploaded = files.upload()

# Move the file to the 'data' directory
os.makedirs('data', exist_ok=True)
# Out:
#      <input type="file" id="files-5c43091a-82c0-44c2-9424-f404d2b95a48" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5c43091a-82c0-44c2-9424-f404d2b95a48">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print ("Displaying the distinct categories of resume and the number of records belonging to each category:\n\n")
print (data1['Category'].value_counts())
# Out:
# Displaying the distinct categories of resume and the number of records belonging to each category:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Category'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
doc1=tb(train_data[0][0])
doc2=tb(train_data[1][0])
doc3=tb(train_data[2][0])
doc4=tb(train_data[3][0])
doc5=tb(train_data[4][0])

# %%
def tf(word,blob):
  return blob.words.count(word)/len(blob.words)
  ## the number of documents containing the word

def n_containing(word,bloblist):
  return sum(1 for blob in bloblist if word in blob.words)

def idf(word,bloblist):
  return math.log(len(bloblist)/(1+n_containing(word,bloblist)))

def tfidf(word,blob,bloblist):
  return tf(word,blob)*idf(word,bloblist)

# %%
import nltk
nltk.download('punkt_tab')
bloblist = [doc1,doc2,doc3,doc4,doc5]
for i, blob in enumerate(bloblist):
  print("Top resumes in the lot:")
  scores= {word: tfidf(word,blob,bloblist) for word in blob.words}
  sorted_words= sorted(scores.items(), key=lambda x:x[1], reverse=True)
  for word, score in sorted_words[:3]:
    print("\tWord: {},TF-IDF:{}".format(word,round(score,5)))
  print("\n")
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Top resumes in the lot:
# 	Word: Years,TF-IDF:0.02569
# 	Word: Senior,TF-IDF:0.01285
# 	Word: APEX,TF-IDF:0.01285
#
#
# Top resumes in the lot:
# 	Word: ➢,TF-IDF:0.02765
# 	Word: testing,TF-IDF:0.02388
# 	Word: Test,TF-IDF:0.01331
#
#
# Top resumes in the lot:
# 	Word: The,TF-IDF:0.02071
# 	Word: has,TF-IDF:0.01238
# 	Word: Retail,TF-IDF:0.00991
#
#
# Top resumes in the lot:
# 	Word: AND,TF-IDF:0.02884
# 	Word: Of,TF-IDF:0.02753
# 	Word: The,TF-IDF:0.02704
#
#
# Top resumes in the lot:
# 	Word: JAVA,TF-IDF:0.02089
# 	Word: For,TF-IDF:0.01997
# 	Word: Pune,TF-IDF:0.01194

# %%
import spacy
from spacy.training.example import Example
import csv
import random

# Function to train the NER model with data from the CSV file and save it
def train_and_save_spacy_model(output_dir="TrainedModel/test2", iterations=20):
    nlp = spacy.blank("en")  # Create a blank 'en' model

    # Create a Named Entity Recognition (NER) pipeline
    ner = nlp.add_pipe("ner", name="ner", last=True)
    ner.add_label("SKILL")  # Add the label for skills recognition

    # Load skills data from CSV file and create training data
    TRAIN_DATA = []
    with open('/content/drive/MyDrive/nlp_review/newSkills.csv', newline='', encoding='utf-8') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            skill_text = row[0].strip()  # Skill text from the CSV row
            if skill_text:  # Check for non-empty skill text
                doc = nlp.make_doc(skill_text)
                entities = [(0, len(skill_text), "SKILL")]
                TRAIN_DATA.append((doc, {"entities": entities}))

    # Begin training
    nlp.begin_training()

    # Iterate through training data
    for itn in range(iterations):
        random.shuffle(TRAIN_DATA)
        losses = {}
        # Create examples and update the model
        for text, annotations in TRAIN_DATA:
            example = Example.from_dict(text, annotations)
            nlp.update([example], drop=0.5, losses=losses)

        print("Iteration:", itn+1, "Loss:", losses)

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# Process the text in train_data
doc1 = nlp(train_data[0][0])
doc2 = nlp(train_data[1][0])
doc3 = nlp(train_data[2][0])

# You can now extract entities, etc.
for doc in [doc1, doc2, doc3]:
    for ent in doc.ents:
        print(ent.text, ent.label_)
# Out:
# Govardhana K PERSON
# Software Engineer PERSON
# Bengaluru GPE
# Karnataka GPE
# Karnataka - Email PERSON
# b2de315d95905b68 PERSON
# 5 Years 6 DATE
# 4 Month DATE
# PL-SQL PERSON
# Designations & Promotions ORG
# Karnataka -   PERSON
# January 2018 DATE
# Karnataka -   PERSON
# November 2016 to December 2017 DATE
# Karnataka -   PERSON
# January 2014 to October 2016 DATE
# Associate Consultant  Oracle -  Bangalore PERSON
# Karnataka -   PERSON
# November 2012 to December 2013 DATE
# EDUCATION GPE
# B.E in Computer Science Engineering  Adithya Institute of Technology -   ORG
# Tamil Nadu PERSON
# September 2008 to June 2012 DATE
# APEX LOC
# Less than 1 year DATE
# Data Structures ORG
# 3 years DATE
# 5 years DATE
# Oracle ( ORG
# 5 years DATE
# Algorithms PERSON
# 3 years DATE
# Core Java PERSON
# Data Structures & Algorithms ORG
# Oracle PL-SQL ORG
# Sales Force PERSON
# APEX LOC
# Jdeveloper GPE
# NetBeans ORG
# Eclipse PRODUCT
# SQL ORG
# PL/SQL Developer ORG
# ...

# %%
train_data[0][0]
# Out:
# 'Govardhana K Senior Software Engineer  Bengaluru, Karnataka, Karnataka - Email me on Indeed: indeed.com/r/Govardhana-K/ b2de315d95905b68  Total IT experience 5 Years 6 Months Cloud Lending Solutions INC 4 Month • Salesforce Developer Oracle 5 Years 2 Month • Core Java Developer Languages Core Java, Go Lang Oracle PL-SQL programming, Sales Force Developer with APEX.  Designations & Promotions  Willing to relocate: Anywhere  WORK EXPERIENCE  Senior Software Engineer  Cloud Lending Solutions -  Bangalore, Karnataka -  January 2018 to Present  Present  Senior Consultant  Oracle -  Bangalore, Karnataka -  November 2016 to December 2017  Staff Consultant  Oracle -  Bangalore, Karnataka -  January 2014 to October 2016  Associate Consultant  Oracle -  Bangalore, Karnataka -  November 2012 to December 2013  EDUCATION  B.E in Computer Science Engineering  Adithya Institute of Technology -  Tamil Nadu  September 2008 to June 2012  https://www.indeed.com/r/Govardhana-K/b2de315d95905b68?isid=rex
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
def tf(word,blob):
  return blob.words.count(word)/len(blob.words)
  ## the number of documents containing the word

def n_containing(word,bloblist):
  return sum(1 for blob in bloblist if word in blob.words)

def idf(word,bloblist):
  return math.log(len(bloblist)/(1+n_containing(word,bloblist)))

def tfidf(word,blob,bloblist):
  return tf(word,blob)*idf(word,bloblist)

# %%
# !python -m textblob.download_corpora
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# Finished.

# %%
# !pip install tokenization

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
docc1 = nlp("Microsoft is a tech company.")
Y = docc1

from nltk.tokenize import word_tokenize
import spacy

nlp = spacy.load("en_core_web_sm")  # Load spaCy model

X = "Microsoft"
Y = nlp("This is a MNC Company].")  # spaCy Doc

# Convert spaCy Doc to string before tokenizing
X_list = word_tokenize(X)
Y_list = word_tokenize(Y.text)  # Convert Y to string

print(X_list, Y_list)
# Out:
# ['Microsoft'] ['This', 'is', 'a', 'MNC', 'Company', ']', '.']

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('stopwords')

X ="Microsoft"
Y =docc1

# tokenization
X_list = word_tokenize(X)
Y_list = word_tokenize(Y.text)

# sw contains the list of stopwords
sw = stopwords.words('english')
l1 =[];l2 =[]

# remove stop words from the string
X_set = {w for w in X_list if not w in sw}
Y_set = {w for w in Y_list if not w in sw}

# form a set containing keywords of both strings
rvector = X_set.union(Y_set)
for w in rvector:
    if w in X_set: l1.append(1) # create a vector
    else: l1.append(0)
    if w in Y_set: l2.append(1)
    else: l2.append(0)
c = 0

# cosine formula
for i in range(len(rvector)):
        c+= l1[i]*l2[i]
cosine = c / float((sum(l1)*sum(l2))**0.5)
print("similarity: ", cosine)
# Out:
# similarity:  0.5
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import spacy

nlp = spacy.load("en_core_web_sm")  # Load spaCy model
docc2 = nlp("This is a document.")  # Process text with spaCy
print(docc2.text)  # Ensure it's defined
# Out:
# This is a document.

# %%
from nltk.tokenize import word_tokenize

# Convert SpaCy Doc object to string before tokenizing
Y = str(Y)  # Ensure Y is a string

# Now tokenize
Y_list = word_tokenize(Y)

# %%
docc2
# Out:
# This is a document.

# %%
import spacy
from nltk.tokenize import word_tokenize
import nltk

# Download necessary NLTK data
nltk.download('punkt')

# Load SpaCy model
nlp = spacy.load("en_core_web_sm")

# Define input text
Y = nlp("This is a MNC Company.")  # SpaCy Doc object

# ✅ Extract text from SpaCy Doc before tokenization
Y_text = Y.text

# Tokenization
Y_list = word_tokenize(Y_text)  # ✅ Now passing a clean string

print("Y Tokens:", Y_list)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Y Tokens: ['This', 'is', 'a', 'MNC', 'Company', '.']

# %%
import spacy
import csv
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Download necessary NLTK resources
nltk.download('punkt')
nltk.download('stopwords')

# Load SpaCy model
nlp = spacy.load('en_core_web_sm')

# Example text processing
X = "Microsoft"
Y = nlp("This is a MNC Company.")  # Processed text using SpaCy

# Tokenization
X_list = word_tokenize(X)
Y_list = word_tokenize(Y.text)  # Convert Y to string before tokenizing

# Remove stopwords
sw = set(stopwords.words('english'))
X_set = {w.lower() for w in X_list if w.lower() not in sw}
Y_set = {w.lower() for w in Y_list if w.lower() not in sw}

# Create vectors
rvector = X_set.union(Y_set)
l1, l2 = [], []

for w in rvector:
    l1.append(1 if w in X_set else 0)
    l2.append(1 if w in Y_set else 0)

# Cosine similarity calculation
c = sum(l1[i] * l2[i] for i in range(len(rvector)))
cosine = c / float((sum(l1) * sum(l2))**0.5) if sum(l1) * sum(l2) != 0 else 0

print("Similarity:", cosine)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Similarity: 0.0

# %%
from nltk.tokenize import word_tokenize
import spacy

# Load SpaCy model
nlp = spacy.load("en_core_web_sm")

# Define input text
X = "Microsoft"
Y = nlp("This is a MNC Company.")  # SpaCy Doc object

# Convert SpaCy Doc to a string before tokenization
Y_text = Y.text  # Extract plain text

# Tokenization
X_list = word_tokenize(X)
Y_list = word_tokenize(Y_text)  # Now Y is a string

print("X Tokens:", X_list)
print("Y Tokens:", Y_list)
# Out:
# X Tokens: ['Microsoft']
# Y Tokens: ['This', 'is', 'a', 'MNC', 'Company', '.']

# %%
from nltk.tokenize import word_tokenize
import spacy

# Load SpaCy model
nlp = spacy.load("en_core_web_sm")

# Define input text
X = "Microsoft"
Y = nlp("This is a MNC Company.")  # SpaCy Doc object

# Convert SpaCy Doc to a string before tokenization
Y_text = Y.text  # Extract plain text

# Tokenization
X_list = word_tokenize(X)
Y_list = word_tokenize(Y_text)  # Now Y is a string

print("X Tokens:", X_list)
print("Y Tokens:", Y_list)
# Out:
# X Tokens: ['Microsoft']
# Y Tokens: ['This', 'is', 'a', 'MNC', 'Company', '.']

# %%
import spacy
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')

# Load SpaCy model
nlp = spacy.load("en_core_web_sm")

# Define input text
X = "Microsoft"
Y = nlp("This is a MNC Company.")  # SpaCy Doc object

# ✅ Convert SpaCy Doc to a string before tokenization
Y_text = Y.text  # Extract plain text

# Tokenization
X_list = word_tokenize(X)
Y_list = word_tokenize(Y_text)  # ✅ Pass string, NOT Doc object

print("X Tokens:", X_list)
print("Y Tokens:", Y_list)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# X Tokens: ['Microsoft']
# Y Tokens: ['This', 'is', 'a', 'MNC', 'Company', '.']

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 87.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 104.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 7.2 MB/s eta 0:00:00
# ...

# %%
import re
import fitz
import base64
import streamlit as st
import spacy
import csv
import nltk

# Additional libraries
nltk.download('punkt')

# Load the spaCy model for English
nlp = spacy.load('en_core_web_sm')

def load_keywords(file_path):
    with open(file_path, 'r') as file:
        reader = csv.reader(file)
        return set(row[0] for row in reader)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def extract_name(doc):
    for ent in doc.ents:
        if ent.label_ == 'PERSON':
            names = ent.text.split()
            if len(names) >= 2 and names[0].istitle() and names[1].istitle():
                return names[0], ' '.join(names[1:])
    return "", ""

# %%
def calculate_resume_score(resume_info):
    score = 0
    if resume_info['first_name'] and resume_info['last_name']:
        score += 25
    if resume_info['email']:
        score += 25
    if resume_info['degree_major']:
        score += 25
    if resume_info['skills']:
        score += 25
    return score

# %%
def extract_resume_info(doc1):
    first_lines = '\n'.join(doc1.text.splitlines()[:10])
    first_name, last_name = extract_name(doc1)
    email = extract_email(doc1)
    skills = extract_skills(doc1)
    degree_major = extract_major(doc1)
    experience = extract_experience(doc1)

    return {'first_name': first_name, 'last_name': last_name, 'email': email, 'degree_major': degree_major, 'skills': skills, 'experience': experience}
